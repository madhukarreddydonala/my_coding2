# %%
import pandas as pd
import numpy as np
reviews_datasets=pd.read_csv("Reviews.csv")
reviews_datasets=reviews_datasets.head(1000)
reviews_datasets.dropna()
# Out:
#        Id   ProductId          UserId                      ProfileName  \
# 0       1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1       2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2       3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3       4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4       5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ..    ...         ...             ...                              ...
# 995   996  B006F2NYI2  A1D3F6UI1RTXO0                           Swopes
# 996   997  B006F2NYI2   AF50D40Y85TV3                          Mike A.
# 997   998  B006F2NYI2  A3G313KLWDG3PW                          kefka82
# 998   999  B006F2NYI2  A3NIDDT7E7JIFW                  V. B. Brookshaw
# 999  1000  B006F2NYI2  A132DJVI37RB4X                        Scottdrum
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
reviews_datasets['Text'][350]
# Out:
# 'These chocolate covered espresso beans are wonderful!  The chocolate is very dark and rich and the "bean" inside is a very delightful blend of flavors with just enough caffine to really give it a zing.'

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect=CountVectorizer(max_df=0.8,min_df=2,stop_words='english')
doc_term_matrix=count_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
doc_term_matrix
# Out:
# <1000x2697 sparse matrix of type '<class 'numpy.int64'>'
# 	with 25471 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatenDirichAllocation
LDA=LantentDirichleAllocation(n_components,random_state=42)

LDA.fit(doc_term_matrix)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from sklearn.decomposition import LatenDirichAllocation
#       2 LDA=LantentDirichleAllocation(n_components,random_state=42)
#       4 LDA.fit(doc_term_matrix)
#
# ImportError: cannot import name 'LatenDirichAllocation' from 'sklearn.decomposition' (C:\Users\madhu\anaconda3\Lib\site-packages\sklearn\decomposition\__init__.py)

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=n_components, random_state=42)

LDA.fit(doc_term_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 from sklearn.decomposition import LatentDirichletAllocation
# ----> 2 LDA = LatentDirichletAllocation(n_components=n_components, random_state=42)
#       4 LDA.fit(doc_term_matrix)
#
# NameError: name 'n_components' is not defined

# %%
pip install -U scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 882.6 kB/s eta 0:00:12
#    - -------------------------------------- 0.5/11.1 MB 882.6 kB/s eta 0:00:12
#    - -------------------------------------- 0.5/11.1 MB 882.6 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/11.1 MB 568.6 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/11.1 MB 568.6 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/11.1 MB 568.6 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/11.1 MB 568.6 kB/s eta 0:00:19
#    --- ------------------------------------ 1.0/11.1 MB 437.6 kB/s eta 0:00:23
#    --- ------------------------------------ 1.0/11.1 MB 437.6 kB/s eta 0:00:23
# ...

# %%
import random
for i in range(10):
    random_id=random.randint(0,len(count_vect.get_features_names_out()))
    print(count_vect.get_feature_names_out[random_id])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 3
#       1 import random
#       2 for i in range(10):
# ----> 3     random_id=random.randint(0,len(count_vect.get_features_names_out()))
#       4     print(count_vect.get_feature_names_out[random_id])
#
# AttributeError: 'CountVectorizer' object has no attribute 'get_features_names_out'

# %%
import random

for i in range(10):
    random_id = random.randint(0, len(count_vect.get_feature_names_out()) - 1)
    print(count_vect.get_feature_names_out()[random_id])
# Out:
# popcorn
# slight
# 2012
# carrying
# slowly
# fiance
# 50
# stop
# tequila
# sunflower

# %%
first_topic=LDA.components_[0]

# %%
top_topic_words=first_topic.argsort()[-10:]

# %%
for i in top_topic_words:
    print(count_vect.get_feature_names_out()[i])

# %%
for i,topic in enumerate(LDA.component_):
    print(f'TOP 10 words for topic #{i}:')
    print([count_vect.get_features_names_out() [i] for i in topic.argsort()[-10:]])
    print('\n')
